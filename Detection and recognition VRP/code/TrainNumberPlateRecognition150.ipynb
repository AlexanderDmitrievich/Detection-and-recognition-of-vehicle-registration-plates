# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Загрузка датасета

# %%
# !unzip /content/gdrive/MyDrive/archivemodified.zip
# Out:
# Archive:  /content/gdrive/MyDrive/archivemodified.zip
# replace classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: classes.txt
# replace test/images/screenshot_1664704636694.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace test/images/screenshot_1664704636694.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: test/images/screenshot_1664704636694.png
#   inflating: test/images/screenshot_1664704639331.png
#   inflating: test/images/screenshot_1664704642016.png
#   inflating: test/images/screenshot_1664704644928.png
#   inflating: test/images/screenshot_1664704646787.png
#   inflating: test/images/screenshot_1664704648798.png
#   inflating: test/images/screenshot_1664704650328.png
#   inflating: test/images/screenshot_1664704651629.png
#   inflating: test/images/screenshot_1664704654305.png
#   inflating: test/images/screenshot_1664704657039.png
#   inflating: test/labels/screenshot_1664704636694.txt
# ...

# %% [markdown]
# Загрузка модели

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.5/513.5 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 27.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.78 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.9/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/dataset.yaml epochs=150 imgsz=640 batch=24 project = 'PlateRecogn' name = plate
# Out:
# Ultralytics YOLOv8.0.78 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/PlateRecogn/plate/weights/best.pt conf=0.55 source= /content/test/images save=True save_txt = True
